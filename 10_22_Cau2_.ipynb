# %%
import nltk
import re
import os
from underthesea import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
# #Read file text
folder_path = r"D:\Y2023-2024_S1\10_KPW\10_22_FInalLAB_Ch4\Data Preprocessing"
file_list = []
texts = []
# Liệt kê tất cả các tệp trong thư mục
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_list.append(filename)
for filename in file_list:
    with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
        text = file.read()
        texts.append(text)

combined_text = ' '.join(texts)

#################################
##### Exploring Text Data #######
#################################
#print("List of Datasets:",text_pre)
print("Number of words: ",len(combined_text))
words = word_tokenize(combined_text)
# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in words)

## show only th top 50 results
print(frequency_dist.most_common(50))

## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)

from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)
#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Number of words:  37513
# [('quán', 172), ('k', 164), ('đi', 119), ('ko', 100), ('món', 82), ('xe', 76), ('nhân_viên', 74), ('kem', 72), ('non', 67), ('uống', 65), ('chỗ', 59), ('giá', 56), ('hơi', 56), ('gọi', 55), ('phục_vụ', 53), ('lắm', 51), ('thử', 46), ('trà', 46), ('mấy', 44), ('đc', 41), ('tiền', 41), ('ng', 40), ('n', 37), ('đông', 37), ('sữa', 34), ('không_gain', 32), ('kêu', 28), ('gà', 28), ('vé', 28), ('đồ_ăn', 27), ('m', 27), ('ghé', 26), ('bảo', 26), ('tạm', 25), ('bàn', 24), ('song', 24), ('thịt', 24), ('chất_lượng', 23), ('ma', 23), ('nv', 23), ('nướng', 23), ('đồ', 22), ('hai', 22), ('t', 22), ('miếng', 22), ('i', 20), ('mùi', 20), ('c', 19), ('đem', 19), ('mì', 19)]
